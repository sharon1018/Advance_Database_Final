# %%
# %load_ext autoreload
# %autoreload 2
# Supress default INFO logging  (Hide Info)

import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import logging
import collections
logging.root.handlers = []  # Jupyter messes up logging so needs a reset
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
from smart_open import smart_open 
import pandas as pd
import numpy as np
from numpy import random
from collections import Counter
import heapq #check n largest
import json
import warnings
from sqlalchemy import create_engine 
import nltk
import seaborn as sns

# %%
def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

# %%
bath_path = r'C:/Users/asus/Downloads/ADB_final/'

computer_security_and_networks = json.load(open(bath_path + r'computer-security-and-networks.json', encoding='utf8'))
algorithms = json.load(open(bath_path + r'algorithms.json', encoding='utf8'))
cloud_computing = json.load(open(bath_path + r'cloud-computing.json', encoding='utf8'))
data_management = json.load(open(bath_path + r'data-management.json', encoding='utf8'))
design_and_product = json.load(open(bath_path + r'design-and-product.json', encoding='utf8'))
electrical_engineering = json.load(open(bath_path + r'electrical-engineering.json', encoding='utf8'))
math_and_logic = json.load(open(bath_path + r'math-and-logic.json', encoding='utf8'))
mobile_and_web_development = json.load(open(bath_path + r'mobile-and-web-development.json', encoding='utf8'))
networking = json.load(open(bath_path + r'networking.json', encoding='utf8'))
probability_and_statistics = json.load(open(bath_path + r'probability-and-statistics.json', encoding='utf8'))
security = json.load(open(bath_path + r'security.json', encoding='utf8'))
machine_learning = json.load(open(bath_path + r'machine-learning.json', encoding='utf8'))
data_analysis = json.load(open(bath_path + r'data-analysis.json', encoding='utf8'))
software_development = json.load(open(bath_path + r'software-development.json', encoding='utf8'))

all_data = computer_security_and_networks + \
algorithms + \
cloud_computing + \
data_management + \
design_and_product + \
electrical_engineering + \
math_and_logic + \
mobile_and_web_development + \
networking + \
probability_and_statistics + \
security + \
machine_learning + \
data_analysis + \
software_development

# %%
len(all_data)
# Out:
# 881

# %%
title=[]; week_data=[]; target_audience=[]; created_by=[]; teach_by=[]
week_data_title=[]; course_info=[]; department=[]; week_data_desc=[]
package_num=[];package_name=[]; level=[]; rating=[]; index=[]
# teach_by, week_data: 多值
for n in range(len(all_data)):
    for i in range(len(all_data[n]['teach_by'])):
            title.append(all_data[n]['title'])
            target_audience.append(all_data[n]['target_audience'])
            created_by.append(all_data[n]['created_by'])
            course_info.append(all_data[n]['course_info'])
            package_num.append(all_data[n]['package_num'])
            package_name.append(all_data[n]['package_name'])
            level.append(all_data[n]['level'])
            rating.append(all_data[n]['rating'])
            teach_by.append(list((all_data[n]['teach_by'][i].values()))[0])  
            department.append(list((all_data[n]['teach_by'][i].values()))[1])

# %%
data = pd.DataFrame({'title': title,
                    'target_audience': target_audience,
                    'created_by' : created_by,  
                    'course_info': course_info,
                    'teach_by': teach_by,
                     'department': department,
                     'level': level,
                     'rating': rating,
                     'package_num': package_num,
                     'package_name': package_name          
                    },
                    columns = ['title', 'course_info', 'target_audience', 'created_by','teach_by',
                               'department','package_num','package_name', 'level','rating'])

# %%
data
# Out:
#                                                title  \
# 0            Bitcoin and Cryptocurrency Technologies
# 1                                     Cryptography I
# 2  Google Cloud Platform Fundamentals: Core Infra...
# 3                 G Suite Administrator Fundamentals
# 4                                    Usable Security
#
#                                          course_info  \
# 0  About this course: To really understand what i...
# 1  About this course: Cryptography is an indispen...
# 2  About this course: <<< ATTENTION >>> Learners ...
# 3  About this course: G Suite Administrator Funda...
# 4  About this course: This course focuses on how ...
#
#                                      target_audience  \
# 0                                               None
# 1                                               None
# 2  Who is this class for: This specialization is ...
# 3  Who is this class for: This class is intended ...
# 4                                               None
#
#                              created_by               teach_by  \
# 0                  Princeton University       Arvind Narayanan
# 1                   Stanford University              Dan Boneh
# 2                          Google Cloud  Google Cloud Training
# 3                          Google Cloud  Google Cloud Training
# 4  University of Maryland, College Park       Jennifer Golbeck
#
#                        department package_num  \
# 0                Computer Science        None
# 1                Computer Science        None
# 2                            None           1
# 3                            None        None
# 4  Human-Computer Interaction Lab           1
#
#                                         package_name         level rating
# 0                                               None          None    4.7
# 1                                               None          None    4.8
# 2  Architecting with Google Cloud Platform Specia...  Intermediate    4.6
# 3                                               None      Beginner    4.5
# 4                      Cybersecurity Specialization           None    4.5

# %%
data =  data.drop_duplicates(subset='title')

# %%
for i, row in data.iterrows():
    if not isEnglish(row.title):
        data.drop(i, inplace=True)

# %%
len(data.title.unique())
# Out:
# 608

# %%
title=[]; created_by=[]; course_info=[]
data_title=[]; data_desc=[]; data_video=[]
# teach_by, week_data: 多值
for n in range(len(all_data)):
    week_data_title=[];  week_data_desc=[];week_data_video=[]
    title.append(all_data[n]['title'])
    created_by.append(all_data[n]['created_by'])
    for i in range(len(all_data[n]['week_data'])):
        week_data_desc.append(all_data[n]['week_data'][i]['description'])
        week_data_title.append(all_data[n]['week_data'][i]['title'])
        week_data_video += all_data[n]['week_data'][i]['video']
    data_title.append(week_data_title)
    data_desc.append(week_data_desc)
    data_video.append(week_data_video)

# %%
data_created_by = pd.DataFrame({'title': title,
                    'created_by':created_by},
                    columns = ['title', 'created_by'])

data_detail = pd.DataFrame({     
                    'week_data_desc': data_desc,
                    'week_data_title': data_title,
                    'week_data_video': data_video
                    },
                    columns = ['week_data_desc', 'week_data_title','week_data_video'])

# %%
data_created_by.drop_duplicates(subset= 'title', inplace=True)

# %%
for i, row in data_created_by.iterrows():
    if not isEnglish(row.title):
        data_created_by.drop(i, inplace=True)

# %%
data_detail = pd.merge(data_created_by, data_detail, left_index=True, right_index=True, how="left")

# %%
data_detail.head()

# %%
for i, row in data_detail.iterrows():
    if len(row.week_data_video) == 0:
        data_detail.drop(i, inplace=True)

# %%
data_detail = data_detail.reset_index(drop=True)

# %%
nlp = spacy.load('en')

# %%
week_video_list = []
for video_data in data_detail.week_data_video:
    video_str = ''
    x = ' '.join(video_data)
    doc = nlp(x.lower())
    for token in doc:
        if not token.is_stop and token.is_alpha:
            video_str += token.lemma_
            video_str += ' '
    week_video_list.append(video_str)

# %%
data_detail['week_data_video_str'] = pd.Series(week_video_list)
data_detail.dropna(inplace=True)
data_detail = data_detail.reset_index(drop=True)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorize = TfidfVectorizer(max_df=150)
bows = vectorize.fit(data_detail.week_data_video_str)
document_matrix = bows.transform(data_detail.week_data_video_str).toarray()

# %%
document_matrix.shape

# %%
f = bows.get_feature_names()

# %%
from sklearn.metrics.pairwise import cosine_similarity
result = cosine_similarity(document_matrix)

# %%
data_detail.loc[np.argsort(result[20])[::-1], :]

# %%
## build title & Top-5 relation

def get_nth_relation(uid, n_th):
    return data_detail.loc[np.argsort(result[uid])[::-1][n_th], :]['title']

title_relation_df = pd.DataFrame(data_detail['title'])
title_relation_df['UID'] = list(range(len(data_detail)))

top_n = 5
for i in range(1, top_n+1):
    str_i = str(i)
    title_relation_df['relate_'+str_i] = title_relation_df['UID'].apply(lambda x: get_nth_relation(x, i))

title_relation_df.head(5)

# %%
df = pd.merge(title_relation_df, data, on='title', how='left')

# %%
df.head()

# %%
from py2neo import Graph

graph = Graph(password='pwd')

# %%
graph.delete_all()

# %%
from py2neo import Node
institute_dict = {}
for created_by in set(data.created_by):
    institute_dict[created_by] = Node("Institute", name=created_by)
    graph.create(institute_dict[created_by])

# %%
len(set(teach_dict))
# Out:
# 491

# %%
teach_dict = {}
for teach_by in set(data.teach_by):
    teach_dict[teach_by] = Node("Teacher", name=teach_by)
    graph.create(teach_dict[teach_by])

# %%
from py2neo import Relationship
for i, row in data.iterrows():
    x = teach_dict[row.teach_by]
    y = institute_dict[row.created_by]
    graph.create(Relationship(x, "from", y))

# %%
course_dict = {}
for i, row in df.iterrows():
    course_dict[row.title] = Node("Course", name=row.title, rating=row.rating, level=row.level)
    graph.create(course_dict[row.title])

# %%
from py2neo import Graph

graph = Graph()

# %%
data.group_by()
# Out:
# 2017-12-28 21:55:41,836 : INFO : > Sending batch request with 2 jobs
# 2017-12-28 21:55:41,852 : INFO : > {0} POST cypher {"query":"MATCH ()-[r]->()\nDELETE r"}
# 2017-12-28 21:55:41,867 : INFO : > {1} POST cypher {"query":"MATCH (n)\nDELETE n"}
# 2017-12-28 21:55:41,877 : INFO : > POST http://localhost:7474/db/data/batch [164]
# 2017-12-28 21:55:41,897 : INFO : ~ Reconnecting (connection aborted)
# 2017-12-28 21:55:42,911 : INFO : > POST http://localhost:7474/db/data/batch [164]
# 2017-12-28 21:55:43,326 : INFO : < 200 OK [141]
# 2017-12-28 21:55:43,326 : INFO : < Received batch response for 2 jobs
# 2017-12-28 21:55:43,326 : INFO : < Discarding batch response

# %%
from py2neo import Node
institute_dict = {}
for created_by in set(data.created_by):
    institute_dict[created_by] = Node("Institute", name=created_by)
    graph.create(institute_dict[created_by])
# Out:
# 2017-12-28 21:55:43,639 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Shanghai Jiao Tong University'}}
# 2017-12-28 21:55:43,641 : INFO : > POST http://localhost:7474/db/data/cypher [106]
# 2017-12-28 21:55:43,651 : INFO : < 200 OK [1406]
# 2017-12-28 21:55:43,658 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'CentraleSupélec'}}
# 2017-12-28 21:55:43,661 : INFO : > POST http://localhost:7474/db/data/cypher [97]
# 2017-12-28 21:55:43,668 : INFO : < 200 OK [1379]
# 2017-12-28 21:55:43,670 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'The University of North Carolina at Chapel Hill, The University of Edinburgh'}}
# 2017-12-28 21:55:43,672 : INFO : > POST http://localhost:7474/db/data/cypher [153]
# 2017-12-28 21:55:43,678 : INFO : < 200 OK [1453]
# 2017-12-28 21:55:43,680 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Alberta'}}
# 2017-12-28 21:55:43,682 : INFO : > POST http://localhost:7474/db/data/cypher [98]
# 2017-12-28 21:55:43,687 : INFO : < 200 OK [1384]
# 2017-12-28 21:55:43,689 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Michigan'}}
# 2017-12-28 21:55:43,690 : INFO : > POST http://localhost:7474/db/data/cypher [99]
# 2017-12-28 21:55:43,695 : INFO : < 200 OK [1399]
# 2017-12-28 21:55:43,696 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Rutgers the State University of New Jersey'}}
# 2017-12-28 21:55:43,698 : INFO : > POST http://localhost:7474/db/data/cypher [119]
# 2017-12-28 21:55:43,704 : INFO : < 200 OK [1405]
# 2017-12-28 21:55:43,707 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Virginia'}}
# 2017-12-28 21:55:43,709 : INFO : > POST http://localhost:7474/db/data/cypher [99]
# 2017-12-28 21:55:43,718 : INFO : < 200 OK [1399]
# 2017-12-28 21:55:43,720 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Stanford University'}}
# 2017-12-28 21:55:43,723 : INFO : > POST http://localhost:7474/db/data/cypher [96]
# 2017-12-28 21:55:43,729 : INFO : < 200 OK [1396]
# 2017-12-28 21:55:43,732 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Colorado Boulder'}}
# 2017-12-28 21:55:43,734 : INFO : > POST http://localhost:7474/db/data/cypher [107]
# 2017-12-28 21:55:43,739 : INFO : < 200 OK [1407]
# 2017-12-28 21:55:43,740 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of London, Goldsmiths, University of London'}}
# 2017-12-28 21:55:43,744 : INFO : > POST http://localhost:7474/db/data/cypher [131]
# 2017-12-28 21:55:43,750 : INFO : < 200 OK [1431]
# 2017-12-28 21:55:43,752 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Toronto'}}
# 2017-12-28 21:55:43,753 : INFO : > POST http://localhost:7474/db/data/cypher [98]
# 2017-12-28 21:55:43,758 : INFO : < 200 OK [1398]
# 2017-12-28 21:55:43,760 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'The Ohio State University'}}
# 2017-12-28 21:55:43,761 : INFO : > POST http://localhost:7474/db/data/cypher [102]
# 2017-12-28 21:55:43,766 : INFO : < 200 OK [1402]
# 2017-12-28 21:55:43,768 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University System of Georgia'}}
# 2017-12-28 21:55:43,769 : INFO : > POST http://localhost:7474/db/data/cypher [105]
# 2017-12-28 21:55:43,774 : INFO : < 200 OK [1405]
# 2017-12-28 21:55:43,776 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Northwestern University'}}
# 2017-12-28 21:55:43,778 : INFO : > POST http://localhost:7474/db/data/cypher [100]
# 2017-12-28 21:55:43,782 : INFO : < 200 OK [1400]
# 2017-12-28 21:55:43,784 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Princeton University'}}
# 2017-12-28 21:55:43,786 : INFO : > POST http://localhost:7474/db/data/cypher [97]
# 2017-12-28 21:55:43,792 : INFO : < 200 OK [1397]
# 2017-12-28 21:55:43,794 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of California, San Diego'}}
# 2017-12-28 21:55:43,797 : INFO : > POST http://localhost:7474/db/data/cypher [112]
# 2017-12-28 21:55:43,802 : INFO : < 200 OK [1412]
# 2017-12-28 21:55:43,805 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Cisco'}}
# 2017-12-28 21:55:43,808 : INFO : > POST http://localhost:7474/db/data/cypher [82]
# 2017-12-28 21:55:43,814 : INFO : < 200 OK [1382]
# 2017-12-28 21:55:43,816 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Washington'}}
# 2017-12-28 21:55:43,817 : INFO : > POST http://localhost:7474/db/data/cypher [101]
# 2017-12-28 21:55:43,822 : INFO : < 200 OK [1401]
# 2017-12-28 21:55:43,824 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'École normale supérieure'}}
# 2017-12-28 21:55:43,826 : INFO : > POST http://localhost:7474/db/data/cypher [111]
# 2017-12-28 21:55:43,832 : INFO : < 200 OK [1403]
# 2017-12-28 21:55:43,834 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Rochester'}}
# 2017-12-28 21:55:43,837 : INFO : > POST http://localhost:7474/db/data/cypher [100]
# 2017-12-28 21:55:43,842 : INFO : < 200 OK [1400]
# 2017-12-28 21:55:43,844 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'IBM'}}
# 2017-12-28 21:55:43,846 : INFO : > POST http://localhost:7474/db/data/cypher [80]
# 2017-12-28 21:55:43,851 : INFO : < 200 OK [1380]
# 2017-12-28 21:55:43,854 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'The University of Tokyo'}}
# 2017-12-28 21:55:43,857 : INFO : > POST http://localhost:7474/db/data/cypher [100]
# 2017-12-28 21:55:43,862 : INFO : < 200 OK [1400]
# 2017-12-28 21:55:43,865 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Macquarie University'}}
# 2017-12-28 21:55:43,867 : INFO : > POST http://localhost:7474/db/data/cypher [97]
# 2017-12-28 21:55:43,871 : INFO : < 200 OK [1397]
# 2017-12-28 21:55:43,874 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'emlyon business school'}}
# 2017-12-28 21:55:43,875 : INFO : > POST http://localhost:7474/db/data/cypher [99]
# 2017-12-28 21:55:43,880 : INFO : < 200 OK [1399]
# 2017-12-28 21:55:43,883 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'The University of Melbourne'}}
# 2017-12-28 21:55:43,885 : INFO : > POST http://localhost:7474/db/data/cypher [104]
# 2017-12-28 21:55:43,890 : INFO : < 200 OK [1404]
# 2017-12-28 21:55:43,892 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'The University of Melbourne, The Chinese University of Hong Kong'}}
# 2017-12-28 21:55:43,894 : INFO : > POST http://localhost:7474/db/data/cypher [141]
# 2017-12-28 21:55:43,900 : INFO : < 200 OK [1441]
# 2017-12-28 21:55:43,903 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Universitat Pompeu Fabra of Barcelona, Stanford University'}}
# 2017-12-28 21:55:43,905 : INFO : > POST http://localhost:7474/db/data/cypher [135]
# 2017-12-28 21:55:43,910 : INFO : < 200 OK [1435]
# 2017-12-28 21:55:43,913 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'The Hong Kong University of Science and Technology'}}
# 2017-12-28 21:55:43,915 : INFO : > POST http://localhost:7474/db/data/cypher [127]
# 2017-12-28 21:55:43,920 : INFO : < 200 OK [1427]
# 2017-12-28 21:55:43,922 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'deeplearning.ai'}}
# 2017-12-28 21:55:43,924 : INFO : > POST http://localhost:7474/db/data/cypher [92]
# 2017-12-28 21:55:43,928 : INFO : < 200 OK [1392]
# 2017-12-28 21:55:43,931 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of London'}}
# 2017-12-28 21:55:43,932 : INFO : > POST http://localhost:7474/db/data/cypher [97]
# 2017-12-28 21:55:43,937 : INFO : < 200 OK [1397]
# 2017-12-28 21:55:43,939 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Autodesk'}}
# 2017-12-28 21:55:43,942 : INFO : > POST http://localhost:7474/db/data/cypher [85]
# 2017-12-28 21:55:43,953 : INFO : < 200 OK [1385]
# 2017-12-28 21:55:43,956 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'EIT Digital '}}
# 2017-12-28 21:55:43,959 : INFO : > POST http://localhost:7474/db/data/cypher [89]
# 2017-12-28 21:55:43,972 : INFO : < 200 OK [1389]
# 2017-12-28 21:55:43,974 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Technical University of Denmark (DTU)'}}
# 2017-12-28 21:55:43,976 : INFO : > POST http://localhost:7474/db/data/cypher [114]
# 2017-12-28 21:55:43,982 : INFO : < 200 OK [1414]
# 2017-12-28 21:55:43,984 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University at Buffalo, The State University of New York'}}
# 2017-12-28 21:55:43,986 : INFO : > POST http://localhost:7474/db/data/cypher [132]
# 2017-12-28 21:55:43,992 : INFO : < 200 OK [1432]
# 2017-12-28 21:55:43,994 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Emory University'}}
# 2017-12-28 21:55:43,998 : INFO : > POST http://localhost:7474/db/data/cypher [93]
# 2017-12-28 21:55:44,004 : INFO : < 200 OK [1393]
# 2017-12-28 21:55:44,007 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of California, Davis'}}
# 2017-12-28 21:55:44,009 : INFO : > POST http://localhost:7474/db/data/cypher [108]
# 2017-12-28 21:55:44,015 : INFO : < 200 OK [1408]
# 2017-12-28 21:55:44,017 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Yonsei University'}}
# 2017-12-28 21:55:44,019 : INFO : > POST http://localhost:7474/db/data/cypher [94]
# 2017-12-28 21:55:44,024 : INFO : < 200 OK [1394]
# 2017-12-28 21:55:44,028 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Yandex'}}
# 2017-12-28 21:55:44,030 : INFO : > POST http://localhost:7474/db/data/cypher [83]
# 2017-12-28 21:55:44,036 : INFO : < 200 OK [1383]
# 2017-12-28 21:55:44,039 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'PwC'}}
# 2017-12-28 21:55:44,041 : INFO : > POST http://localhost:7474/db/data/cypher [80]
# 2017-12-28 21:55:44,046 : INFO : < 200 OK [1380]
# 2017-12-28 21:55:44,049 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of California, Santa Cruz'}}
# 2017-12-28 21:55:44,051 : INFO : > POST http://localhost:7474/db/data/cypher [113]
# 2017-12-28 21:55:44,055 : INFO : < 200 OK [1413]
# 2017-12-28 21:55:44,059 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Google Daydream Impact'}}
# 2017-12-28 21:55:44,060 : INFO : > POST http://localhost:7474/db/data/cypher [99]
# 2017-12-28 21:55:44,066 : INFO : < 200 OK [1399]
# 2017-12-28 21:55:44,069 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'National Research University Higher School of Economics'}}
# 2017-12-28 21:55:44,071 : INFO : > POST http://localhost:7474/db/data/cypher [132]
# 2017-12-28 21:55:44,076 : INFO : < 200 OK [1432]
# 2017-12-28 21:55:44,079 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'The Pennsylvania State University'}}
# 2017-12-28 21:55:44,081 : INFO : > POST http://localhost:7474/db/data/cypher [110]
# 2017-12-28 21:55:44,086 : INFO : < 200 OK [1410]
# 2017-12-28 21:55:44,088 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'The University of Edinburgh, Universidad ORT Uruguay'}}
# 2017-12-28 21:55:44,090 : INFO : > POST http://localhost:7474/db/data/cypher [129]
# 2017-12-28 21:55:44,096 : INFO : < 200 OK [1429]
# 2017-12-28 21:55:44,099 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Nanjing University'}}
# 2017-12-28 21:55:44,101 : INFO : > POST http://localhost:7474/db/data/cypher [95]
# 2017-12-28 21:55:44,106 : INFO : < 200 OK [1395]
# 2017-12-28 21:55:44,109 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Stanford University, The University of British Columbia'}}
# 2017-12-28 21:55:44,111 : INFO : > POST http://localhost:7474/db/data/cypher [132]
# 2017-12-28 21:55:44,116 : INFO : < 200 OK [1432]
# 2017-12-28 21:55:44,118 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Vanderbilt University'}}
# 2017-12-28 21:55:44,119 : INFO : > POST http://localhost:7474/db/data/cypher [98]
# 2017-12-28 21:55:44,125 : INFO : < 200 OK [1398]
# 2017-12-28 21:55:44,127 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of New Mexico'}}
# 2017-12-28 21:55:44,129 : INFO : > POST http://localhost:7474/db/data/cypher [101]
# 2017-12-28 21:55:44,134 : INFO : < 200 OK [1401]
# 2017-12-28 21:55:44,136 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'New York University Tandon School of Engineering'}}
# 2017-12-28 21:55:44,138 : INFO : > POST http://localhost:7474/db/data/cypher [125]
# 2017-12-28 21:55:44,143 : INFO : < 200 OK [1425]
# 2017-12-28 21:55:44,146 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Illinois at Urbana-Champaign'}}
# 2017-12-28 21:55:44,147 : INFO : > POST http://localhost:7474/db/data/cypher [119]
# 2017-12-28 21:55:44,151 : INFO : < 200 OK [1419]
# 2017-12-28 21:55:44,153 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'École Polytechnique Fédérale de Lausanne'}}
# 2017-12-28 21:55:44,156 : INFO : > POST http://localhost:7474/db/data/cypher [132]
# 2017-12-28 21:55:44,161 : INFO : < 200 OK [1420]
# 2017-12-28 21:55:44,164 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Hebrew University of Jerusalem'}}
# 2017-12-28 21:55:44,166 : INFO : > POST http://localhost:7474/db/data/cypher [107]
# 2017-12-28 21:55:44,171 : INFO : < 200 OK [1407]
# 2017-12-28 21:55:44,174 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Amsterdam'}}
# 2017-12-28 21:55:44,176 : INFO : > POST http://localhost:7474/db/data/cypher [100]
# 2017-12-28 21:55:44,180 : INFO : < 200 OK [1400]
# 2017-12-28 21:55:44,182 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'MongoDB Inc.'}}
# 2017-12-28 21:55:44,184 : INFO : > POST http://localhost:7474/db/data/cypher [89]
# 2017-12-28 21:55:44,189 : INFO : < 200 OK [1389]
# 2017-12-28 21:55:44,191 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Moscow Institute of Physics and Technology'}}
# 2017-12-28 21:55:44,192 : INFO : > POST http://localhost:7474/db/data/cypher [119]
# 2017-12-28 21:55:44,197 : INFO : < 200 OK [1419]
# 2017-12-28 21:55:44,199 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Wesleyan University'}}
# 2017-12-28 21:55:44,200 : INFO : > POST http://localhost:7474/db/data/cypher [96]
# 2017-12-28 21:55:44,205 : INFO : < 200 OK [1396]
# 2017-12-28 21:55:44,208 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Rice University'}}
# 2017-12-28 21:55:44,211 : INFO : > POST http://localhost:7474/db/data/cypher [92]
# 2017-12-28 21:55:44,219 : INFO : < 200 OK [1392]
# 2017-12-28 21:55:44,222 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Universitat Autònoma de Barcelona'}}
# 2017-12-28 21:55:44,224 : INFO : > POST http://localhost:7474/db/data/cypher [115]
# 2017-12-28 21:55:44,230 : INFO : < 200 OK [1411]
# 2017-12-28 21:55:44,234 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Georgia Institute of Technology'}}
# 2017-12-28 21:55:44,237 : INFO : > POST http://localhost:7474/db/data/cypher [108]
# 2017-12-28 21:55:44,247 : INFO : < 200 OK [1408]
# 2017-12-28 21:55:44,250 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Tecnológico de Monterrey'}}
# 2017-12-28 21:55:44,252 : INFO : > POST http://localhost:7474/db/data/cypher [106]
# 2017-12-28 21:55:44,257 : INFO : < 200 OK [1402]
# 2017-12-28 21:55:44,260 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Cape Town'}}
# 2017-12-28 21:55:44,263 : INFO : > POST http://localhost:7474/db/data/cypher [100]
# 2017-12-28 21:55:44,268 : INFO : < 200 OK [1400]
# 2017-12-28 21:55:44,270 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Indian School of Business'}}
# 2017-12-28 21:55:44,272 : INFO : > POST http://localhost:7474/db/data/cypher [102]
# 2017-12-28 21:55:44,277 : INFO : < 200 OK [1402]
# 2017-12-28 21:55:44,281 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'ESSEC Business School'}}
# 2017-12-28 21:55:44,283 : INFO : > POST http://localhost:7474/db/data/cypher [98]
# 2017-12-28 21:55:44,288 : INFO : < 200 OK [1398]
# 2017-12-28 21:55:44,291 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'UNSW Australia (The University of New South Wales)'}}
# 2017-12-28 21:55:44,293 : INFO : > POST http://localhost:7474/db/data/cypher [127]
# 2017-12-28 21:55:44,297 : INFO : < 200 OK [1427]
# 2017-12-28 21:55:44,300 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'California Institute of the Arts'}}
# 2017-12-28 21:55:44,302 : INFO : > POST http://localhost:7474/db/data/cypher [109]
# 2017-12-28 21:55:44,307 : INFO : < 200 OK [1409]
# 2017-12-28 21:55:44,309 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of California, San Diego, National Research University Higher School of Economics'}}
# 2017-12-28 21:55:44,311 : INFO : > POST http://localhost:7474/db/data/cypher [169]
# 2017-12-28 21:55:44,316 : INFO : < 200 OK [1469]
# 2017-12-28 21:55:44,320 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Intel'}}
# 2017-12-28 21:55:44,323 : INFO : > POST http://localhost:7474/db/data/cypher [82]
# 2017-12-28 21:55:44,327 : INFO : < 200 OK [1382]
# 2017-12-28 21:55:44,329 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'The State University of New York'}}
# 2017-12-28 21:55:44,331 : INFO : > POST http://localhost:7474/db/data/cypher [109]
# 2017-12-28 21:55:44,336 : INFO : < 200 OK [1409]
# 2017-12-28 21:55:44,338 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Erasmus University Rotterdam'}}
# 2017-12-28 21:55:44,340 : INFO : > POST http://localhost:7474/db/data/cypher [105]
# 2017-12-28 21:55:44,345 : INFO : < 200 OK [1405]
# 2017-12-28 21:55:44,349 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Duke University'}}
# 2017-12-28 21:55:44,350 : INFO : > POST http://localhost:7474/db/data/cypher [92]
# 2017-12-28 21:55:44,355 : INFO : < 200 OK [1392]
# 2017-12-28 21:55:44,357 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Michigan State University'}}
# 2017-12-28 21:55:44,359 : INFO : > POST http://localhost:7474/db/data/cypher [102]
# 2017-12-28 21:55:44,364 : INFO : < 200 OK [1402]
# 2017-12-28 21:55:44,367 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Maryland, College Park'}}
# 2017-12-28 21:55:44,369 : INFO : > POST http://localhost:7474/db/data/cypher [113]
# 2017-12-28 21:55:44,374 : INFO : < 200 OK [1413]
# 2017-12-28 21:55:44,376 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Eindhoven University of Technology'}}
# 2017-12-28 21:55:44,377 : INFO : > POST http://localhost:7474/db/data/cypher [111]
# 2017-12-28 21:55:44,382 : INFO : < 200 OK [1411]
# 2017-12-28 21:55:44,384 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of California, Irvine'}}
# 2017-12-28 21:55:44,387 : INFO : > POST http://localhost:7474/db/data/cypher [109]
# 2017-12-28 21:55:44,391 : INFO : < 200 OK [1409]
# 2017-12-28 21:55:44,393 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'National Research Tomsk State University'}}
# 2017-12-28 21:55:44,396 : INFO : > POST http://localhost:7474/db/data/cypher [117]
# 2017-12-28 21:55:44,400 : INFO : < 200 OK [1417]
# 2017-12-28 21:55:44,402 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Google Cloud'}}
# 2017-12-28 21:55:44,403 : INFO : > POST http://localhost:7474/db/data/cypher [89]
# 2017-12-28 21:55:44,408 : INFO : < 200 OK [1389]
# 2017-12-28 21:55:44,411 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'The University of Edinburgh'}}
# 2017-12-28 21:55:44,414 : INFO : > POST http://localhost:7474/db/data/cypher [104]
# 2017-12-28 21:55:44,419 : INFO : < 200 OK [1404]
# 2017-12-28 21:55:44,423 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Colorado System'}}
# 2017-12-28 21:55:44,425 : INFO : > POST http://localhost:7474/db/data/cypher [106]
# 2017-12-28 21:55:44,433 : INFO : < 200 OK [1406]
# 2017-12-28 21:55:44,436 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'McMaster University'}}
# 2017-12-28 21:55:44,437 : INFO : > POST http://localhost:7474/db/data/cypher [96]
# 2017-12-28 21:55:44,442 : INFO : < 200 OK [1396]
# 2017-12-28 21:55:44,445 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Korea Advanced Institute of Science and Technology'}}
# 2017-12-28 21:55:44,447 : INFO : > POST http://localhost:7474/db/data/cypher [127]
# 2017-12-28 21:55:44,452 : INFO : < 200 OK [1427]
# 2017-12-28 21:55:44,456 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Columbia University'}}
# 2017-12-28 21:55:44,457 : INFO : > POST http://localhost:7474/db/data/cypher [96]
# 2017-12-28 21:55:44,462 : INFO : < 200 OK [1396]
# 2017-12-28 21:55:44,466 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Pennsylvania'}}
# 2017-12-28 21:55:44,468 : INFO : > POST http://localhost:7474/db/data/cypher [103]
# 2017-12-28 21:55:44,472 : INFO : < 200 OK [1403]
# 2017-12-28 21:55:44,476 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'The University of Chicago'}}
# 2017-12-28 21:55:44,478 : INFO : > POST http://localhost:7474/db/data/cypher [102]
# 2017-12-28 21:55:44,483 : INFO : < 200 OK [1402]
# 2017-12-28 21:55:44,485 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Johns Hopkins University'}}
# 2017-12-28 21:55:44,487 : INFO : > POST http://localhost:7474/db/data/cypher [101]
# 2017-12-28 21:55:44,492 : INFO : < 200 OK [1401]
# 2017-12-28 21:55:44,495 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'The University of Sydney'}}
# 2017-12-28 21:55:44,497 : INFO : > POST http://localhost:7474/db/data/cypher [101]
# 2017-12-28 21:55:44,502 : INFO : < 200 OK [1401]
# 2017-12-28 21:55:44,506 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Icahn School of Medicine at Mount Sinai'}}
# 2017-12-28 21:55:44,508 : INFO : > POST http://localhost:7474/db/data/cypher [116]
# 2017-12-28 21:55:44,513 : INFO : < 200 OK [1416]
# 2017-12-28 21:55:44,516 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'West Virginia University'}}
# 2017-12-28 21:55:44,518 : INFO : > POST http://localhost:7474/db/data/cypher [101]
# 2017-12-28 21:55:44,523 : INFO : < 200 OK [1401]
# 2017-12-28 21:55:44,526 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Houston System'}}
# 2017-12-28 21:55:44,528 : INFO : > POST http://localhost:7474/db/data/cypher [105]
# 2017-12-28 21:55:44,534 : INFO : < 200 OK [1405]
# 2017-12-28 21:55:44,537 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Minnesota'}}
# 2017-12-28 21:55:44,539 : INFO : > POST http://localhost:7474/db/data/cypher [100]
# 2017-12-28 21:55:44,544 : INFO : < 200 OK [1400]
# 2017-12-28 21:55:44,547 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Johns Hopkins University, University of Colorado Boulder'}}
# 2017-12-28 21:55:44,549 : INFO : > POST http://localhost:7474/db/data/cypher [133]
# 2017-12-28 21:55:44,554 : INFO : < 200 OK [1433]
# 2017-12-28 21:55:44,556 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Zurich'}}
# 2017-12-28 21:55:44,559 : INFO : > POST http://localhost:7474/db/data/cypher [97]
# 2017-12-28 21:55:44,563 : INFO : < 200 OK [1397]
# 2017-12-28 21:55:44,566 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'University of Copenhagen'}}
# 2017-12-28 21:55:44,567 : INFO : > POST http://localhost:7474/db/data/cypher [101]
# 2017-12-28 21:55:44,572 : INFO : < 200 OK [1401]
# 2017-12-28 21:55:44,575 : INFO : execute 'CREATE (_0:Institute {_0})\nRETURN _0' {'_0': {'name': 'Institut Mines-Télécom'}}
# 2017-12-28 21:55:44,577 : INFO : > POST http://localhost:7474/db/data/cypher [109]
# 2017-12-28 21:55:44,582 : INFO : < 200 OK [1401]

# %%
teach_dict[teach_by]
# Out:
# <Node graph='http://localhost:7474/db/data/' ref='node/1158' labels={'Teacher'} properties={'name': 'Daniel E. Koditschek'}>

# %%
teach_dict = {}
for teach_by in set(data.teach_by):
    teach_dict[teach_by] = Node("Teacher", name=teach_by)
    graph.create(teach_dict[teach_by])
# Out:
# 2017-12-28 21:55:44,998 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Shannon Bradshaw'}}
# 2017-12-28 21:55:44,999 : INFO : > POST http://localhost:7474/db/data/cypher [91]
# 2017-12-28 21:55:45,005 : INFO : < 200 OK [1391]
# 2017-12-28 21:55:45,007 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Emily Fox'}}
# 2017-12-28 21:55:45,009 : INFO : > POST http://localhost:7474/db/data/cypher [84]
# 2017-12-28 21:55:45,015 : INFO : < 200 OK [1384]
# 2017-12-28 21:55:45,018 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Lana Yarosh'}}
# 2017-12-28 21:55:45,019 : INFO : > POST http://localhost:7474/db/data/cypher [86]
# 2017-12-28 21:55:45,024 : INFO : < 200 OK [1386]
# 2017-12-28 21:55:45,026 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Cristiano Guarana'}}
# 2017-12-28 21:55:45,029 : INFO : > POST http://localhost:7474/db/data/cypher [92]
# 2017-12-28 21:55
: INFO : > POST http://localhost:7474/db/data/cypher [95]
# 2017-12-28 21:55:46,747 : INFO : < 200 OK [1395]
# 2017-12-28 21:55:46,749 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Ilya Breyman'}}
# 2017-12-28 21:55:46,751 : INFO : > POST http://localhost:7474/db/data/cypher [87]
# 2017-12-28 21:55:46,757 : INFO : < 200 OK [1387]
# 2017-12-28 21:55:46,759 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Tim Roughgarden'}}
# 2017-12-28 21:55:46,761 : INFO : > POST http://localhost:7474/db/data/cypher [90]
# 2017-12-28 21:55:46,767 : INFO : < 200 OK [1390]
# 2017-12-28 21:55:46,770 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Evgeny Sokolov'}}
# 2017-12-28 21:55:46,772 : INFO : > POST http://localhost:7474/db/data/cypher [89]
# 2017-12-28 21:55:46,778 : INFO : < 200 OK [1389]
# 2017-12-28 21:55:46,781 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Marios Michailidis'}}
# 2017-12-28 21:55:46,783 : INFO : > POST http://localhost:7474/db/data/cypher [93]
# 2017-12-28 21:55:46,788 : INFO : < 200 OK [1393]
# 2017-12-28 21:55:46,790 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Alma Salnaja'}}
# 2017-12-28 21:55:46,792 : INFO : > POST http://localhost:7474/db/data/cypher [87]
# 2017-12-28 21:55:46,796 : INFO : < 200 OK [1387]
# 2017-12-28 21:55:46,798 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Dr. Joyelle Harris'}}
# 2017-12-28 21:55:46,800 : INFO : > POST http://localhost:7474/db/data/cypher [93]
# 2017-12-28 21:55:46,804 : INFO : < 200 OK [1393]
# 2017-12-28 21:55:46,807 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Robert  Clark'}}
# 2017-12-28 21:55:46,809 : INFO : > POST http://localhost:7474/db/data/cypher [88]
# 2017-12-28 21:55:46,813 : INFO : < 200 OK [1388]
# 2017-12-28 21:55:46,815 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Parham Aarabi'}}
# 2017-12-28 21:55:46,817 : INFO : > POST http://localhost:7474/db/data/cypher [88]
# 2017-12-28 21:55:46,822 : INFO : < 200 OK [1388]
# 2017-12-28 21:55:46,825 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'George Kapetanios'}}
# 2017-12-28 21:55:46,826 : INFO : > POST http://localhost:7474/db/data/cypher [92]
# 2017-12-28 21:55:46,831 : INFO : < 200 OK [1392]
# 2017-12-28 21:55:46,834 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Laurent Franck'}}
# 2017-12-28 21:55:46,836 : INFO : > POST http://localhost:7474/db/data/cypher [89]
# 2017-12-28 21:55:46,841 : INFO : < 200 OK [1389]
# 2017-12-28 21:55:46,842 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Melissa Clarke'}}
# 2017-12-28 21:55:46,844 : INFO : > POST http://localhost:7474/db/data/cypher [89]
# 2017-12-28 21:55:46,848 : INFO : < 200 OK [1389]
# 2017-12-28 21:55:46,851 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'David Van Kleeck'}}
# 2017-12-28 21:55:46,853 : INFO : > POST http://localhost:7474/db/data/cypher [91]
# 2017-12-28 21:55:46,858 : INFO : < 200 OK [1391]
# 2017-12-28 21:55:46,860 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Pavel Shvechikov'}}
# 2017-12-28 21:55:46,862 : INFO : > POST http://localhost:7474/db/data/cypher [91]
# 2017-12-28 21:55:46,866 : INFO : < 200 OK [1391]
# 2017-12-28 21:55:46,870 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Norberto Leite'}}
# 2017-12-28 21:55:46,871 : INFO : > POST http://localhost:7474/db/data/cypher [89]
# 2017-12-28 21:55:46,876 : INFO : < 200 OK [1389]
# 2017-12-28 21:55:46,878 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Rahul Rai'}}
# 2017-12-28 21:55:46,880 : INFO : > POST http://localhost:7474/db/data/cypher [84]
# 2017-12-28 21:55:46,884 : INFO : < 200 OK [1384]
# 2017-12-28 21:55:46,886 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Dr Mary Ann Weitnauer'}}
# 2017-12-28 21:55:46,888 : INFO : > POST http://localhost:7474/db/data/cypher [96]
# 2017-12-28 21:55:46,892 : INFO : < 200 OK [1396]
# 2017-12-28 21:55:46,896 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Manel Martínez-Ramón'}}
# 2017-12-28 21:55:46,898 : INFO : > POST http://localhost:7474/db/data/cypher [105]
# 2017-12-28 21:55:46,902 : INFO : < 200 OK [1397]
# ...
# 2017-12-28 21:55:48,894 : INFO : > POST http://localhost:7474/db/data/cypher [118]
# 2017-12-28 21:55:48,898 : INFO : < 200 OK [1418]
# 2017-12-28 21:55:48,901 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Chan-Byoung Chae'}}
# 2017-12-28 21:55:48,902 : INFO : > POST http://localhost:7474/db/data/cypher [91]
# 2017-12-28 21:55:48,907 : INFO : < 200 OK [1391]
# 2017-12-28 21:55:48,910 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Robert Duvall'}}
# 2017-12-28 21:55:48,911 : INFO : > POST http://localhost:7474/db/data/cypher [88]
# 2017-12-28 21:55:48,916 : INFO : < 200 OK [1388]
# 2017-12-28 21:55:48,918 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Arvind Narayanan'}}
# 2017-12-28 21:55:48,920 : INFO : > POST http://localhost:7474/db/data/cypher [91]
# 2017-12-28 21:55:48,924 : INFO : < 200 OK [1391]
# 2017-12-28 21:55:48,926 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Justin-Nicholas Toyama '}}
# 2017-12-28 21:55:48,928 : INFO : > POST http://localhost:7474/db/data/cypher [98]
# 2017-12-28 21:55:48,932 : INFO : < 200 OK [1398]
# 2017-12-28 21:55:48,935 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Andrei Zimovnov'}}
# 2017-12-28 21:55:48,937 : INFO : > POST http://localhost:7474/db/data/cypher [90]
# 2017-12-28 21:55:48,942 : INFO : < 200 OK [1390]
# 2017-12-28 21:55:48,945 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Théotime Vaillant'}}
# 2017-12-28 21:55:48,947 : INFO : > POST http://localhost:7474/db/data/cypher [97]
# 2017-12-28 21:55:48,952 : INFO : < 200 OK [1393]
# 2017-12-28 21:55:48,956 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Mung Chiang'}}
# 2017-12-28 21:55:48,959 : INFO : > POST http://localhost:7474/db/data/cypher [86]
# 2017-12-28 21:55:48,964 : INFO : < 200 OK [1386]
# 2017-12-28 21:55:48,968 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Reza Farivar'}}
# 2017-12-28 21:55:48,970 : INFO : > POST http://localhost:7474/db/data/cypher [87]
# 2017-12-28 21:55:48,974 : INFO : < 200 OK [1387]
# 2017-12-28 21:55:48,977 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Roberto Cazzolla Gatti'}}
# 2017-12-28 21:55:48,979 : INFO : > POST http://localhost:7474/db/data/cypher [97]
# 2017-12-28 21:55:48,983 : INFO : < 200 OK [1397]
# 2017-12-28 21:55:48,985 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Mikhail Trofimov'}}
# 2017-12-28 21:55:48,987 : INFO : > POST http://localhost:7474/db/data/cypher [91]
# 2017-12-28 21:55:48,992 : INFO : < 200 OK [1391]
# 2017-12-28 21:55:48,994 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Kirby Kohlmorgen'}}
# 2017-12-28 21:55:48,996 : INFO : > POST http://localhost:7474/db/data/cypher [91]
# 2017-12-28 21:55:49,000 : INFO : < 200 OK [1391]
# 2017-12-28 21:55:49,003 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Sven-Erik Gryning'}}
# 2017-12-28 21:55:49,004 : INFO : > POST http://localhost:7474/db/data/cypher [92]
# 2017-12-28 21:55:49,009 : INFO : < 200 OK [1392]
# 2017-12-28 21:55:49,012 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': '
: INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Jennifer Campbell'}}
# 2017-12-28 21:55:49,474 : INFO : > POST http://localhost:7474/db/data/cypher [92]
# 2017-12-28 21:55:49,480 : INFO : < 200 OK [1392]
# 2017-12-28 21:55:49,483 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Kevin Dunn'}}
# 2017-12-28 21:55:49,485 : INFO : > POST http://localhost:7474/db/data/cypher [85]
# 2017-12-28 21:55:49,490 : INFO : < 200 OK [1385]
# 2017-12-28 21:55:49,494 : INFO : execute 'CREATE (_0:Teacher {_0})\nRETURN _0' {'_0': {'name': 'Daniel E. Koditschek'}}
# 2017-12-28 21:55:49,496 : INFO : > POST http://localhost:7474/db/data/cypher [95]
# 2017-12-28 21:55:49,501 : INFO : < 200 OK [1395]

# %%
from py2neo import Relationship
for i, row in data.iterrows():
    x = teach_dict[row.teach_by]
    y = institute_dict[row.created_by]
    graph.create(Relationship(x, "from", y))
# Out:
# 2017-12-28 21:55:49,752 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1195, '_0n0': 1697}
# 2017-12-28 21:55:49,753 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,760 : INFO : < 200 OK [3237]
# 2017-12-28 21:55:49,764 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1208, '_0n0': 1574}
# 2017-12-28 21:55:49,766 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,772 : INFO : < 200 OK [3229]
# 2017-12-28 21:55:49,775 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1265, '_0n0': 1542}
# 2017-12-28 21:55:49,777 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,782 : INFO : < 200 OK [3238]
# 2017-12-28 21:55:49,785 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1265, '_0n0': 1542}
# 2017-12-28 21:55:49,787 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,792 : INFO : < 200 OK [3234]
# 2017-12-28 21:55:49,795 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1263, '_0n0': 1406}
# 2017-12-28 21:55:49,797 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,801 : INFO : < 200 OK [3257]
# 2017-12-28 21:55:49,806 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1196, '_0n0': 1620}
# 2017-12-28 21:55:49,808 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,813 : INFO : < 200 OK [3221]
# 2017-12-28 21:55:49,817 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1194, '_0n0': 1554}
# 2017-12-28 21:55:49,819 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,824 : INFO : < 200 OK [3250]
# 2017-12-28 21:55:49,828 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1235, '_0n0': 1742}
# 2017-12-28 21:55:49,829 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,834 : INFO : < 200 OK [3270]
# 2017-12-28 21:55:49,837 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1206, '_0n0': 1751}
# 2017-12-28 21:55:49,839 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,844 : INFO : < 200 OK [3237]
# 2017-12-28 21:55:49,847 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1265, '_0n0': 1542}
# 2017-12-28 21:55:49,849 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,854 : INFO : < 200 OK [3234]
# 2017-12-28 21:55:49,857 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1263, '_0n0': 1530}
# 2017-12-28 21:55:49,859 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,864 : INFO : < 200 OK [3254]
# 2017-12-28 21:55:49,867 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1265, '_0n0': 1542}
# 2017-12-28 21:55:49,869 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,874 : INFO : < 200 OK [3234]
# 2017-12-28 21:55:49,878 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1266, '_0n0': 1587}
# 2017-12-28 21:55:49,880 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,885 : INFO : < 200 OK [3245]
# 2017-12-28 21:55:49,889 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1219, '_0n0': 1324}
# 2017-12-28 21:55:49,891 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,896 : INFO : < 200 OK [3248]
# 2017-12-28 21:55:49,899 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1219, '_0n0': 1663}
# 2017-12-28 21:55:49,901 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,906 : INFO : < 200 OK [3250]
# 2017-12-28 21:55:49,909 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1219, '_0n0': 1680}
# 2017-12-28 21:55:49,911 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,916 : INFO : < 200 OK [3241]
# 2017-12-28 21:55:49,919 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1265, '_0n0': 1542}
# 2017-12-28 21:55:49,921 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,926 : INFO : < 200 OK [3238]
# 2017-12-28 21:55:49,929 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1196, '_0n0': 1620}
# 2017-12-28 21:55:49,931 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,936 : INFO : < 200 OK [3221]
# 2017-12-28 21:55:49,939 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1265, '_0n0': 1542}
# 2017-12-28 21:55:49,941 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,946 : INFO : < 200 OK [3238]
# 2017-12-28 21:55:49,950 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1266, '_0n0': 1302}
# 2017-12-28 21:55:49,952 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,957 : INFO : < 200 OK [3245]
# 2017-12-28 21:55:49,961 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1266, '_0n0': 1420}
# 2017-12-28 21:55:49,962 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:55:49,967 : INFO : < 200 OK [3247]
# 2017-12-28 21:55:49,971 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1252, '_0n0': 
: INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,092 : INFO : < 200 OK [3228]
# 2017-12-28 21:56:00,094 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1198, '_0n0': 1639}
# 2017-12-28 21:56:00,096 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,101 : INFO : < 200 OK [3226]
# 2017-12-28 21:56:00,103 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1198, '_0n0': 1722}
# 2017-12-28 21:56:00,105 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,110 : INFO : < 200 OK [3228]
# 2017-12-28 21:56:00,112 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1236, '_0n0': 1619}
# 2017-12-28 21:56:00,114 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,118 : INFO : < 200 OK [3271]
# 2017-12-28 21:56:00,122 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1236, '_0n0': 1690}
# 2017-12-28 21:56:00,123 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,128 : INFO : < 200 OK [3279]
# 2017-12-28 21:56:00,131 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1262, '_0n0': 1713}
# 2017-12-28 21:56:00,133 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,137 : INFO : < 200 OK [3237]
# 2017-12-28 21:56:00,139 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1262, '_0n0': 1403}
# 2017-12-28 21:56:00,141 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,146 : INFO : < 200 OK [3242]
# 2017-12-28 21:56:00,150 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1262, '_0n0': 1502}
# 2017-12-28 21:56:00,151 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,156 : INFO : < 200 OK [3240]
# 2017-12-28 21:56:00,160 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1262, '_0n0': 1560}
# 2017-12-28 21:56:00,163 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,168 : INFO : < 200 OK [3243]
# 2017-12-28 21:56:00,172 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1239, '_0n0': 1438}
# 2017-12-28 21:56:00,174 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,182 : INFO : < 200 OK [3236]
# 2017-12-28 21:56:00,186 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1239, '_0n0': 1438}
# 2017-12-28 21:56:00,188 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,193 : INFO : < 200 OK [3240]
# 2017-12-28 21:56:00,198 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1253, '_0n0': 1366}
# 2017-12-28 21:56:00,199 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,204 : INFO : < 200 OK [3254]
# 2017-12-28 21:56:00,206 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1227, '_0n0': 1656}
# 2017-12-28 21:56:00,208 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,213 : INFO : < 200 OK [3257]
# 2017-12-28 21:56:00,218 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1212, '_0n0': 1369}
# 2017-12-28 21:56:00,221 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,224 : INFO : < 200 OK [3254]
# 2017-12-28 21:56:00,228 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1212, '_0n0': 1453}
# 2017-12-28 21:56:00,230 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,235 : INFO : < 200 OK [3258]
# 2017-12-28 21:56:00,237 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1212, '_0n0': 1441}
# 2017-12-28 21:56:00,238 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,243 : INFO : < 200 OK [3262]
# 2017-12-28 21:56:00,246 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1266, '_0n0': 1578}
# 2017-12-28 21:56:00,247 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,252 : INFO : < 200 OK [3265]
# 2017-12-28 21:56:00,256 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1275, '_0n0': 1665}
# 2017-12-28 21:56:00,258 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,262 : INFO : < 200 OK [3246]
# 2017-12-28 21:56:00,266 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1275, '_0n0': 1552}
# 2017-12-28 21:56:00,267 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,275 : INFO : < 200 OK [3247]
# 2017-12-28 21:56:00,280 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1244, '_0n0': 1494}
# 2017-12-28 21:56:00,284 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,291 : INFO : < 200 OK [3231]
# 2017-12-28 21:56:00,294 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1246, '_0n0': 1393}
# 2017-12-28 21:56:00,297 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,303 : INFO : < 200 OK [3248]
# 2017-12-28 21:56:00,307 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1209, '_0n0': 1617}
# 2017-12-28 21:56:00,309 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,314 : INFO : < 200 OK [3279]
# 2017-12-28 21:56:00,318 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1209, '_0n0': 1598}
# 2017-12-28 21:56:00,321 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,327 : INFO : < 200 OK [3286]
# 2017-12-28 21:56:00,330 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1209, '_0n0': 1725}
# 2017-12-28 21:56:00,331 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,336 : INFO : < 200 OK [3279]
# 2017-12-28 21:56:00,339 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1222, '_0n0': 1537}
# 2017-12-28 21:56:00,342 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,346 : INFO : < 200 OK [3237]
# 2017-12-28 21:56:00,350 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1275, '_0n0': 1665}
# 2017-12-28 21:56:00,352 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,356 : INFO : < 200 OK [3250]
# 2017-12-28 21:56:00,360 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1266, '_0n0': 1578}
# 2017-12-28 21:56:00,362 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,367 : INFO : < 200 OK [3265]
# 2017-12-28 21:56:00,370 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1266, '_0n0': 1610}
# 2017-12-28 21:56:00,372 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,376 : INFO : < 200 OK [3254]
# 2017-12-28 21:56:00,380 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1222, '_0n0': 1743}
# 2017-12-28 21:56:00,382 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,387 : INFO : < 200 OK [3235]
# 2017-12-28 21:56:00,391 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1266, '_0n0': 1610}
# 2017-12-28 21:56:00,393 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,399 : INFO : < 200 OK [3254]
# 2017-12-28 21:56:00,404 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1266, '_0n0': 1578}
# 2017-12-28 21:56:00,407 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,412 : INFO : < 200 OK [3265]
# 2017-12-28 21:56:00,415 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1266, '_0n0': 1578}
# 2017-12-28 21:56:00,417 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,422 : INFO : < 200 OK [3265]
# 2017-12-28 21:56:00,425 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1266, '_0n0': 1578}
# 2017-12-28 21:56:00,428 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,434 : INFO : < 200 OK [3265]
# 2017-12-28 21:56:00,436 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1266, '_0n0': 1610}
# 2017-12-28 21:56:00,438 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,444 : INFO : < 200 OK [3254]
# 2017-12-28 21:56:00,448 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1266, '_0n0': 1610}
# 2017-12-28 21:56:00,450 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,455 : INFO : < 200 OK [3254]
# 2017-12-28 21:56:00,459 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1264, '_0n0': 1579}
# 2017-12-28 21:56:00,460 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,465 : INFO : < 200 OK [3258]
# 2017-12-28 21:56:00,469 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1264, '_0n0': 1331}
# 2017-12-28 21:56:00,471 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,475 : INFO : < 200 OK [3256]
# 2017-12-28 21:56:00,478 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1219, '_0n0': 1432}
# 2017-12-28 21:56:00,479 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,484 : INFO : < 200 OK [3254]
# 2017-12-28 21:56:00,488 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1222, '_0n0': 1378}
# 2017-12-28 21:56:00,490 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,494 : INFO : < 200 OK [3237]
# 2017-12-28 21:56:00,497 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1275, '_0n0': 1665}
# 2017-12-28 21:56:00,499 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,504 : INFO : < 200 OK [3250]
# 2017-12-28 21:56:00,508 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1275, '_0n0': 1552}
# 2017-12-28 21:56:00,510 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,516 : INFO : < 200 OK [3247]
# 2017-12-28 21:56:00,519 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1262, '_0n0': 1713}
# 2017-12-28 21:56:00,520 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,526 : INFO : < 200 OK [3241]
# 2017-12-28 21:56:00,528 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1262, '_0n0': 1403}
# 2017-12-28 21:56:00,531 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,536 : INFO : < 200 OK [3242]
# 2017-12-28 21:56:00,538 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1262, '_0n0': 1502}
# 2017-12-28 21:56:00,540 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,548 : INFO : < 200 OK [3244]
# 2017-12-28 21:56:00,552 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1262, '_0n0': 1560}
# 2017-12-28 21:56:00,554 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,560 : INFO : < 200 OK [3243]
# 2017-12-28 21:56:00,565 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1246, '_0n0': 1393}
# 2017-12-28 21:56:00,567 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,572 : INFO : < 200 OK [3248]
# 2017-12-28 21:56:00,576 : INFO : execute 'MATCH (_0n0) WHERE id(_0n0)={_0n0}\nMATCH (_0n1) WHERE id(_0n1)={_0n1}\n\nCREATE (_0n0)-[_0r0:from]->(_0n1)\nRETURN _0n0,_0n1,_0r0' {'_0n1': 1246, '_0n0': 1314}
# 2017-12-28 21:56:00,578 : INFO : > POST http://localhost:7474/db/data/cypher [177]
# 2017-12-28 21:56:00,583 : INFO : < 200 OK [3253]

# %%
data.head()
# Out:
#                                                title  \
# 0            Bitcoin and Cryptocurrency Technologies
# 1                                     Cryptography I
# 2  Google Cloud Platform Fundamentals: Core Infra...
# 3                 G Suite Administrator Fundamentals
# 4                                    Usable Security
#
#                                          course_info  \
# 0  About this course: To really understand what i...
# 1  About this course: Cryptography is an indispen...
# 2  About this course: <<< ATTENTION >>> Learners ...
# 3  About this course: G Suite Administrator Funda...
# 4  About this course: This course focuses on how ...
#
#                                      target_audience  \
# 0                                               None
# 1                                               None
# 2  Who is this class for: This specialization is ...
# 3  Who is this class for: This class is intended ...
# 4                                               None
#
#                              created_by               teach_by  \
# 0                  Princeton University       Arvind Narayanan
# 1                   Stanford University              Dan Boneh
# 2                          Google Cloud  Google Cloud Training
# 3                          Google Cloud  Google Cloud Training
# 4  University of Maryland, College Park       Jennifer Golbeck
#
#                        department package_num  \
# 0                Computer Science        None
# 1                Computer Science        None
# 2                            None           1
# 3                            None        None
# 4  Human-Computer Interaction Lab           1
#
#                                         package_name         level rating
# 0                                               None          None    4.7
# 1                                               None          None    4.8
# 2  Architecting with Google Cloud Platform Specia...  Intermediate    4.6
# 3                                               None      Beginner    4.5
# 4                      Cybersecurity Specialization           None    4.5

# %%
data[data.created_by=='University of Rochester']
# Out:
#                                                  title  \
# 435  Fundamentals of Audio and Music Engineering: P...
# 436  Fundamentals of Audio and Music Engineering: P...
#
#                                            course_info target_audience  \
# 435  About this course: In this course students lea...            None
# 436  About this course: In this course students lea...            None
#
#                   created_by       teach_by  \
# 435  University of Rochester  Robert  Clark
# 436  University of Rochester    Mark  Bocko
#
#                               department package_num package_name level rating
# 435               Mechanical Engineering        None         None  None    4.6
# 436  Electrical and Computer Engineering        None         None  None    4.6

# %%
from vis import draw

options = {"Teacher": "name", 'Institue': 'name'}
draw(graph, options)
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="figure/graph-9a404052-9c20-46a3-9cd6-af3e4ad54ab7.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
df = df.sort_values(by=['package_name', 'package_num'])

# %%
for name, group in df.groupby('package_name')['title']:
    tmp = list(group)
    for i, row in enumerate(tmp):
        if i != 0:
            x = course_dict[tmp[i-1]]
            y = course_dict[row]
            graph.create(Relationship(x, "require", y))

# %%
for name, group in df.groupby('package_name')['title']:
    tmp = list(group)
    for i, row in enumerate(tmp):
        if i != 0:
            x = course_dict[tmp[i-1]]
            y = course_dict[row]
            graph.create(Relationship(x, "require", y))
# Out:
# 403

# %%
for i, row in title_relation_df.iterrows():
    title = row['title']
    for i in range(1, 6):
        x = course_dict[title]
        y = course_dict[row['relate_%s' % i]]
        if df[df.title == title].package_name.values[0] != None:
            if df[df.title == row['relate_%s' % i]].package_name.values[0] != df[df.title == title].package_name.values[0]:
                graph.create(Relationship(x, "similar", y))
        else:
            graph.create(Relationship(x, "similar", y))

# %%
title_relation_df.head()
# Out:
#                                                title  UID  \
# 0            Bitcoin and Cryptocurrency Technologies    0
# 1                                     Cryptography I    1
# 2  Google Cloud Platform Fundamentals: Core Infra...    2
# 3                 G Suite Administrator Fundamentals    3
# 4                                    Usable Security    4
#
#                                        relate_1  \
# 0       Software Design Threats and Mitigations
# 1                                  Cryptography
# 2  Getting Started With Application Development
# 3           Introduction to Systems Engineering
# 4                           Data Science Ethics
#
#                                             relate_2  \
# 0        Cryptographic Hash and Integrity Protection
# 1                             Symmetric Cryptography
# 2  Develop and Deploy Windows Applications on Goo...
# 3                                 The Unix Workbench
# 4                           Games, Sensors and Media
#
#                                             relate_3  \
# 0             Process Mining: Data science in Action
# 1  Basic Cryptography and Programming with Crypto...
# 2  Elastic Cloud Infrastructure: Containers and S...
# 3             Econometrics: Methods and Applications
# 4  Privacy, Reputation, and Identity in a Digital...
#
#                                             relate_4  \
# 0                                   What is a Proof?
# 1         Asymmetric Cryptography and Key Management
# 2      Essential Cloud Infrastructure: Core Services
# 3  Front-End Web UI Frameworks and Tools: Bootstr...
# 4                          Introduction to UI Design
#
#                                             relate_5
# 0  Build Your First Android App (Project-Centered...
# 1         Introduction to Cybersecurity for Business
# 2  Google Cloud Platform Fundamentals for AWS Pro...
# 3                              Introduction to Logic
# 4                         Securing Digital Democracy

# %%
df[-10:-1]
# Out:
#      index                                              title  UID  \
# 585    564            Learn to Program: Crafting Quality Code  564
# 586    566     Audio Signal Processing for Music Applications  566
# 587    567                    A Developer's guide to Node-RED  567
# 588    572  Build a Modern Computer from First Principles:...  572
# 589    573                      C++ For C Programmers, Part B  573
# 590    577  Fundamentals of Parallelism on Intel Architecture  577
# 591    579  Creative Programming for Digital Media & Mobil...  579
# 592    580   Software Architecture for the Internet of Things  580
# 593    584                        Quantitative Model Checking  584
#
#                                               relate_1  \
# 585                                Algorithmic Toolbox
# 586                          Digital Signal Processing
# 587  A developer's guide to the Internet of Things ...
# 588  Build a Modern Computer from First Principles:...
# 589                      C++ For C Programmers, Part A
# 590  Global Warming II: Create Your Own Models in P...
# 591                    Approximation Algorithms Part I
# 592   Software Development Processes and Methodologies
# 593           An Intuitive Introduction to Probability
#
#                                               relate_2  \
# 585                           Programming Fundamentals
# 586  Creative Programming for Digital Media & Mobil...
# 587  Server-side Development with NodeJS, Express a...
# 588              Game Theory II: Advanced Applications
# 589                      Programming Languages, Part A
# 590                      Interactivity with JavaScript
# 591                    Python for Genomic Data Science
# 592  Requirements Gathering for Secure Software Dev...
# 593                        Social Media Data Analytics
#
#                                               relate_3  \
# 585  Divide and Conquer, Sorting and Searching, and...
# 586  Fundamentals of Audio and Music Engineering: P...
# 587                               Accounting Analytics
# 588                         iOS App Development Basics
# 589            Introduction to Programming with MATLAB
# 590  Introduction to Embedded Systems Software and ...
# 591  The Raspberry Pi Platform and Python Programmi...
# 592                              Software Architecture
# 593                              Data-driven Astronomy
#
#                                               relate_4  \
# 585                      Algorithmic Thinking (Part 2)
# 586                      3D Models for Virtual Reality
# 587      Essential Cloud Infrastructure: Core Services
# 588          Business Statistics and Analysis Capstone
# 589                   Cloud Computing Concepts: Part 2
# 590  Responsive Website Basics: Code with HTML, CSS...
# 591         Functional Programming Principles in Scala
# 592                                    Design Patterns
# 593      Designing, Running, and Analyzing Experiments
#
#                                               relate_5  \
# 585  Graph Search, Shortest Paths, and Data Structures
# 586           Responsive Website Tutorial and Examples
# 587  Graph Search, Shortest Paths, and Data Structures
# 588          Developing Android Apps with App Inventor
# 589       Calculus: Single Variable Part 1 - Functions
# 590  Fundamentals of Digital Image and Video Proces...
# 591     Dynamical Modeling Methods for Systems Biology
# 592             Software Processes and Agile Practices
# 593    Control of Nonlinear Spacecraft Attitude Motion
#
#                                            course_info  \
# 585  About this course: Not all programs are create...
# 586  About this course: In this course you will lea...
# 587  About this course: >>> By enrolling in this co...
# 588  About this course: In this project-centered co...
# 589  About this course: This course is for experien...
# 590  About this course: This course will introduce ...
# 591  About this course: This course is for anyone w...
# 592  About this course: This course will teach you ...
# 593  About this course: The integration of ICT (inf...
#
#                                        target_audience  \
# 585                                               None
# 586  Who is this class for: This course is primary ...
# 587  Who is this class for: The course is aimed at ...
# 588  Who is this class for: Do you want to understa...
# 589                                               None
# 590  Who is this class for: For developers of machi...
# 591                                               None
# 592  Who is this class for: You're at the right add...
# 593  Who is this class for: This course is meant fo...
#
#                                             created_by           teach_by  \
# 585                              University of Toronto  Jennifer Campbell
# 586  Universitat Pompeu Fabra of Barcelona, Stanfor...       Xavier Serra
# 587                                                IBM        Brian Innes
# 588                     Hebrew University of Jerusalem    Shimon Schocken
# 589               University of California, Santa Cruz           Ira Pohl
# 590                                              Intel  Andrey Vladimirov
# 591  University of London, Goldsmiths, University o...   Dr Marco Gillies
# 592                                       EIT Digital        Frank Gielen
# 593                                       EIT Digital          Anne Remke
#
#                                             department package_num  \
# 585                     Department of Computer Science        None
# 586  Dept. of Information and Communication Technol...        None
# 587                         IBM Digital Business Group        None
# 588                                   Computer Science        None
# 589                                   Computer Science        None
# 590                               Colfax International        None
# 591  Computing Department, Goldsmiths, University o...        None
# 592  UGent/IBCN: Internet Based Communication Networks        None
# 593                                   Computer Science        None
#
#     package_name         level rating
# 585         None          None    4.5
# 586         None  Intermediate    4.9
# 587         None  Intermediate   None
# 588         None          None    4.9
# 589         None          None    4.2
# 590         None  Intermediate    2.0
# 591         None          None    4.7
# 592         None          None    4.2
# 593         None  Intermediate    4.5

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer

svd = TruncatedSVD(100)
normalizer = Normalizer(copy=False)
lsa = make_pipeline(svd, normalizer)
X = lsa.fit_transform(document_matrix)
inertia_list = []  
for i in range(2,15):
    kmeans = KMeans(n_clusters=i).fit(X)
    inertia_list.append(kmeans.inertia_)

import matplotlib.pyplot as plt
plt.plot(range(2,15), inertia_list, linestyle='-', marker='o')
plt.show()

# %%
![image.png](attachment:image.png)

# %%
#IsDuplicated = data_to_mysql.duplicated()

# %%
# duplicate_course=0
# for i in range(len(data_to_mysql)):
#     if IsDuplicated[i] == True:
#         duplicate_course=duplicate_course+1
#         #print(i)
# print(duplicate_course)

# %%
#data = data_to_mysql.drop_duplicates()

# %%
#data_to_mysql.head()

# %% [markdown]
# ### --------------------------------------------------------------------------------

# %%
### Testing

# %%
# v=[]
# for n in range(len(all_data)):
#     for j in range(len(all_data[n]['week_data'])):     
#         v.append(list((all_data[n]['week_data'][j]).values())[0])
#         #a.append(pd.Series(v).str.cat(sep=''))

# %%
# v= pd.Series(v).str.cat(sep='')
